# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielNovaisProgramador/python_senai_cyberseguranca/blob/My_projects_in_Python/aulasenai1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Para lembrar, para comentar em Python é necessário colocar três aspas ou duas àspas simples.
    Estou na minha primeira aula de Python no Senai'''
# Se usa também o símbolo de "#" para comentar
# Out:
# 'Para lembrar, para comentar em Python é necessário colocar três aspas ou duas àspas simples.\n    Estou na minha primeira aula de Python no Senai'

# %%
print("Hello word!!!")
# Out:
# Hello word!!!

# %%
a = 12
print(a)
# Out:
# 12

# %%
a = 12
print("depois do 11 vêm o",a)
# Out:
# depois do 11 vêm o 12

# %%
a = 12
print("Depois do 11 vêm o",a,"e depois do",a,"vêm o 13")
# Out:
# Depois do 11 vêm o 12 e depois do 12 vêm o 13

# %%
nome_digitado = input("Qual é o seu nome?")
saudacao = nome_digitado + ", boas vindas à sua primeira tarefa"
print(saudacao)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1924552923.py in <cell line: 0>()
# ----> 1 nome_digitado = input("Qual é o seu nome?")
#       2 saudacao = nome_digitado + ", boas vindas à sua primeira tarefa"
#       3 print(saudacao)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
usuario = input("Digite seu nome completo: ")
minha_idade = input("Agora me informe sua idade: ")
informacao_completa = "Seu nome é " + usuario + " e você têm " + minha_idade + " anos."
print(informacao_completa)

# %%
name = input("Qual é o seu nome?")

# %%
print("Boa noite! "+ name +", você têm", len(name),"letras no seu primeiro nome.")

# %%
def acesso_aluno():
  gmail = input("Informe o seu gmail: ")
  senha = input("Agora informe sua senha: ")
  confirmacao_senha = input("Me confirme se o seu gmail é "+ gmail +" e se sua senha é "+ senha +" ?")
  if confirmacao_senha == "sim":
    print("Login realizado com sucesso!")
  else:
    print("Login não realizado com sucesso.")

# %%
acesso_aluno()

# %%
x = "2"
y = x + 2
print(y)

# %%
x = "7"
y = int(x + 8)
print(y)

# %%
a = 8/4
type(a)

# %%
z = int(10/5)
type(z)
print(z)

# %%
#Inteiro (Integer)
type(15)
# Out:
# int

# %%
#Ponto flutuante (float)
type(3.12)
# Out:
# float

# %%
type(2/3)
# Out:
# float

# %%
# Cuidad, resultado de divisões inteiras também aparecerão como Float, pois é acrescentado " ." ao resultado
fracao =4/2
type(fracao)
# Out:
# float

# %%
print(fracao)
# Out:
# 2.0

# %%
#Neste caso podemos onverter o tipo (declaração explicita de varíavel):
fracao = int(4/2)
print(type(fracao))
# Out:
# <class 'int'>

# %%
#cuidado "10" é diferente de 10.
num = "10"
print(num)
print(type(num))
# Out:
# 10
# <class 'str'>

# %%
mult = 4 * num
print(mult)
print(type(mult))
# Out:
# 10101010
# <class 'str'>

# %%
num2 = 10.0
print(num2)
print(type(num2))
# Out:
# 10.0
# <class 'float'>

# %%
mult2 = 2 * num2
print(mult2)
print(type(mult2))
# Out:
# 20.0
# <class 'float'>

# %%
#Cadeia de caracteres (String)
name = "Jack"
film = "Titanic, de 1999"
print(name, "é um personagem do filme", film)
# Out:
# Jack é um personagem do filme Titanic, de 1999

# %%
#Booleano (Boolean)
x = 10
y = 5
isGreater = x > y
isEqual_Correct = x==y
isEqual_Wrong = x=y #Nessa linha o valor da variavel "x" passa para 5, recebendo o valor da váriavel "y". Porque estamos usando o sinal "=" que se refere à comparação. Diferente de "==" que é para se equiparar os valores.
isSmaller = x<y

print(isGreater)
print(type(isGreater))

# %%
'''Desafio da aula do dia 19/09/2025 do curso de Python para cibersecurity solicitado pelo professor Peterson'''
a = 15
b = 2
c = a
a = b
b = c
print(a)
print(b)

# %%
x = 6
y = 17.8

z = x
x = y
y = z
print(x)
print(y)

# %%
#Exemplo com valores.

marvel = "Punisher"
dc = "Batman"
inverso = marvel
marvel = dc
dc = inverso

print(marvel)
print(dc)
